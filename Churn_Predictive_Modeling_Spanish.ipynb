# %% [markdown]
# # Modelado Predictivo para Retención de Clientes

# %% [markdown]
# -----

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Descripción

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Modelado Predictivo para Retención de Clientes en Telecomunicaciones: Caso Interconnect</b><br>
#
# Interconnect, un operador de telecomunicaciones, busca predecir la tasa de cancelación de clientes con un modelo de aprendizaje automático, identificando patrones que indiquen la probabilidad de que un cliente cancele su contrato con datos históricos de contratos, servicios y características de los clientes.
# </div>

# %% [markdown]
# ### Servicios de Interconnect

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Interconnect proporciona principalmente dos tipos de servicios:</b><br>
# ▶ Comunicación por teléfono fijo: El teléfono se puede conectar a varias líneas de manera simultánea.<br>
# ▶ Internet: La red se puede configurar a través de una línea telefónica (DSL, línea de abonado digital) o a través de un cable de fibra óptica.<br><br>
# <b> Algunos otros servicios que ofrece la empresa incluyen:</b> <br>
# ▶ Seguridad en Internet: software antivirus (ProtecciónDeDispositivo) y un bloqueador de sitios web maliciosos (SeguridadEnLínea).<br>
# ▶ Una línea de soporte técnico (SoporteTécnico).<br>
# ▶ Almacenamiento de archivos en la nube y backup de datos (BackupOnline).<br>
# ▶ Streaming de TV (StreamingTV) y directorio de películas (StreamingPelículas)
# La clientela puede elegir entre un pago mensual o firmar un contrato de 1 o 2 años. Puede utilizar varios métodos de pago y recibir una factura electrónica después de una transacción.
# </div>

# %% [markdown]
# ### Objetivo

# %% [markdown]
# <div style="color: #196CC4;">
# Proporcionar a Interconnect una herramienta efectiva para gestionar proactivamente la retención de clientes, a través de un sistema predictivo para permitir a la empresa anticiparse a la cancelación de clientes.<br><br>
# </div>

# %% [markdown]
# ### Recursos

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Los datos consisten en archivos obtenidos de diferentes fuentes:</b><br>
# ▶ contract.csv — información del contrato;<br>
# ▶ personal.csv — datos personales del cliente;<br>
# ▶ internet.csv — información sobre los servicios de Internet;<br>
# ▶ phone.csv — información sobre los servicios telefónicos.<br><br>
# En cada archivo, la columna customerID (ID de cliente) contiene un código único asignado a cada cliente. La información del contrato es válida a partir del 1 de febrero de 2020.
#
# <b>Característica objetivo</b><br>
# ▶ La columna 'EndDate' es igual a 'No'.<br>
# </div>

# %% [markdown]
# ### Metodología

# %% [markdown]
# <div style="color: #196CC4;">
# <ol>
# <li>Inicialización y Análisis Exploratorio de Datos
# <ul>
# <li>Se importan librerías, módulos y 4 datasets: contract.csv, personal.csv, internet.csv y datasets/phone.csv</li>
# <li>Se realiza un entendimiento general de cada uno de los conjuntos de datos con correlaciones preliminares entre variables numéricas y categóricas, identificación de valores ausentes, duplicados y sintaxis.</li>
# <li>Se trabaja con un DataFrame fusionado a partir de la característica 'customerid', que centraliza toda la información de los datasets analizados.</li>
# <li>Se realiza una limpieza inicial de los datos: manteniendo los nombres de las características en minúsculas, tratando los datos ausentes y con el tipo de dato adecuado a la información que contienen.</li>
# <li>Se analizan todos los datos para identificar patrones de comportamiento de clientes y características de cada tipo de contrato:
#
# <ul>
# <li>Estadística descriptiva</li>
# <li>Proporción de contratos activos e inactivos en su totalidad</li>
# <li>Evolución de los tipos de contratos en el tiempo</li>
# <li>Feature Engineering con nuevas características que aporten valor al propósito de la investigación, por ejemplo, característica booleana para verificar contratos activos y no activos y la duración de los contratos</li>
# <li>Análisis exhaustivo de las características del servicio de internet y de los clientes</li>
# <li>Análisis exhaustivo de las características de los tipos de contrataciones, temporalidad de los cargos y métodos de pago</li>
# </ul>
#
# </li>
#
# </ul>
# </li>
#
# <li>Preparación de Datos
#     <ul>
#         <li>Posterior al análisis exhaustivo, se eliminan las características que no aportan valor al propósito del proyecto.</li>
#         <li>Se utiliza "MinMaxScaler" para el preprocesamiento de datos para poner todas las características (features) en una misma escala.</li>
#         <li>Se realiza la codificación de variables: se aplica el tipo de codificación más adecuado a las variables para agilizar el procesamiento con los modelos.</li>
#         <li>Se dividen los datos en conjuntos de entrenamiento, validación y prueba en una proporción de 6 : 2 : 2 para prepararlos para el modelado.</li>
#         <li>Se realiza un análisis del desequilibrio de clases con la variable objetivo 'contract_active' y si hay un desequilibrio significativo, se aplican técnicas de balanceo con submuestreo y sobremuestreo. Posteriormente se validan cuáles conjuntos de datos ya balanceados son más óptimos para esta investigación.</li>
#     </ul>
# </li>
#
# <li>Desarrollo del Modelo
#     <ul>
#         <li>Se seleccionan los modelos más adecuados para este proyecto de clasificación: Regresión Logística, KNN Clasifier, Random Forest, Gradient Boosting Machine (GBM), XGBoost (Extreme Gradient Boosting) y LightGBM (Light Gradient Boosting Machine). También se aplica una variación con validación cruzada a algunos de estos modelos para mejorar su rendimiento.</li>
#         <li>Se entrenan y optimizan los modelos para prever la cancelación de clientes con precisión, haciendo las modificaciones adecuadas a los hiperparámetros.</li>
#         <li>Se trabaja con las métricas AUC-ROC, Accuracy, Precisión, Recall, F1-Score y Matriz de Confusión, todo esto ayuda a seleccionar el mejor modelo predictivo.</li>
#     </ul>
# </li>
#
# <li>Evaluación del Modelo
#     <ul>
#         <li>Se muestra un resumen de las métricas obtenidas con cada uno de los modelos.</li>
#         <li>Se realiza un análisis exhaustivo de los resultados obtenidos y se selecciona el modelo con el mejor rendimiento.</li>
#         <li>Se evalúa el modelo ganador con el conjunto de pruebas y se revisa su desempeño utilizando los mismos hiperparámetros que con el conjunto de entrenamiento.</li>
#     </ul>
# </li>
#
# <li>Informe del proyecto
#     <ul>
#         <li>Se prepara un informe detallado que documenta el proceso, los resultados y las recomendaciones para Interconnect, destacando cómo el modelo predice eficazmente la cancelación de clientes y proporciona una herramienta efectiva para la gestión proactiva de retención de clientes.</li>
#     </ul>
# </li>
#
# </ol>
#
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Información general

# %% [markdown]
# ### Inicialización

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Importación de bibliotecas y carga de datos
# </div>

# %%
# Data treatment
import pandas as pd
import numpy as np

# Time
import time

# Data visualization
import matplotlib.pyplot as plt

# Attractive data visualization
import seaborn as sns

# Shuffle data
from sklearn.utils import shuffle

# Split data
from sklearn.model_selection import train_test_split

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
import xgboost as xgb
import lightgbm as lgb

# Warnings
import warnings

# Metrics
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# Data scale
from sklearn.preprocessing import MinMaxScaler

# %%
# Import data
df_contract = pd.read_csv('datasets/contract.csv')
df_personal = pd.read_csv('datasets/personal.csv')
df_internet = pd.read_csv('datasets/internet.csv')
df_phone = pd.read_csv('datasets/phone.csv')

# %% [markdown]
# ### Despliegue de datasets

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Propiedades generales de los Dataframes
# </div>

# %% [markdown]
# ##### DataFrame Contract

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Se muestran los detalles del contrato de cada usuario
# </div>

# %%
# General Dataframe properties
df_contract.info()
display(df_contract.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# ...

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Valores únicos para las Series y entendimiento de los datos que manejan
# </div>

# %%
# Number of values
nunique_type = df_contract['Type'].nunique()
nunique_billing = df_contract['PaperlessBilling'].nunique()
nunique_payment = df_contract['PaymentMethod'].nunique()

# Unique values
values_type = df_contract['Type'].unique()
values_billing = df_contract['PaperlessBilling'].unique()
values_payment = df_contract['PaymentMethod'].unique()

#------------------------------------------------------------------------------#

# Print "Type" number & values
print(f"Número de valores únicos en la columna 'Type': {nunique_type}")
for value in values_type:
    print(value)

print()

# Print "PaperlessBilling" number & values
print(f"Número de valores únicos en la columna 'PaperlessBilling': {
      nunique_billing}")
for value in values_billing:
    print(value)

print()

# Print "PaymentMethod" number & values
print(f"Número de valores únicos en la columna 'PaymentMethod': {
      nunique_payment}")
for value in values_payment:
    print(value)
# Out:
# Número de valores únicos en la columna 'Type': 3
# Month-to-month
# One year
# Two year
#
# Número de valores únicos en la columna 'PaperlessBilling': 2
# Yes
# No
#
# Número de valores únicos en la columna 'PaymentMethod': 4
# Electronic check
# Mailed check
# Bank transfer (automatic)
# Credit card (automatic)

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Observaciones iniciales:</b><br>
# ▶ No se observan valores ausentes<br>
# ▶ Los nombres de las Series están en mayúsculas y minúsculas, se sugiere convertir todo a minúsculas para trabajar más cómodamente y tener consistencia en los datos<br>
# ▶ La Serie "customerID" es muy importante como identificador único de cada cliente y Serie que permitirá la fusión con otros DataFrames<br>
# ▶ Las Series "BeginDate" y "EndDate" indican la fecha de inicio y fin del contrato (si es 'No', significa que el contrato está activo, además <b>"EndDate" es la característica objetivo)</b><br>
# ▶ La Serie "Type" (tipo de contrato) tiene 3 valores únicos: "Month-to-month", "One year" y "Two year"<br>
# ▶ La Serie "PaperlessBilling" (facturación sin papel) tiene 2 valores únicos: "Yes" y "No"<br>
# ▶ La Serie "PaymentMethod" (método de pago de cada cliente) tiene 4 valores únicos: "Electronic check", "Mailed check", "Bank transfer (automatic)" y "Credit card (automatic)"<br>
# ▶ La Serie "MonthlyCharges" indica los cargos mensuales<br>
# ▶ La Serie "TotalCharges" indica los cargos totales acumulados<br>
#
# *Más adelante será necesario el tratamiento de las variables categóricas en una forma numérica que los algoritmos de aprendizaje automático puedan procesar de manera efectiva.
# </div>

# %% [markdown]
# ##### DataFrame Personal

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Se muestran los datos personales de cada cliente
# </div>

# %%
# General Dataframe properties
df_personal.info()
display(df_personal.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Valores únicos para las Series y entendimiento de los datos que manejan
# </div>

# %%
# Number of values
nunique_gender = df_personal['gender'].nunique()
nunique_citizen = df_personal['SeniorCitizen'].nunique()
nunique_partner = df_personal['Partner'].nunique()
nunique_dependents = df_personal['Dependents'].nunique()

# Unique values
values_gender = df_personal['gender'].unique()
values_citizen = df_personal['SeniorCitizen'].unique()
values_partner = df_personal['Partner'].unique()
values_dependents = df_personal['Dependents'].unique()

# ------------------------------------------------------------------------------#

# Print "gender" number & values
print(f"Número de valores únicos en la columna 'gender': {
      nunique_gender}")
for value in values_gender:
    print(value)

print()

# Print "SeniorCitizen" number & values
print(f"Número de valores únicos en la columna 'SeniorCitizen': {
      nunique_citizen}")
for value in values_citizen:
    print(value)

print()

# Print "Partner" number & values
print(f"Número de valores únicos en la columna 'Partner': {
      nunique_partner}")
for value in values_partner:
    print(value)

print()

# Print "Dependents" number & values
print(f"Número de valores únicos en la columna 'Dependents': {
      nunique_dependents}")
for value in values_dependents:
    print(value)

print()
# Out:
# Número de valores únicos en la columna 'gender': 2
# Female
# Male
#
# Número de valores únicos en la columna 'SeniorCitizen': 2
# 0
# 1
#
# Número de valores únicos en la columna 'Partner': 2
# Yes
# No
#
# Número de valores únicos en la columna 'Dependents': 2
# No
# Yes

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Observaciones iniciales:</b><br>
# ▶ No se observan valores ausentes<br>
# ▶ Los nombres de las Series están en mayúsculas y minúsculas, se sugiere convertir todo a minúsculas para trabajar más cómodamente y tener consistencia en los datos<br>
# ▶ Nuevamente la Serie "customerID" como identificador de cada cliente<br>
# ▶ La Serie "gender" (género del cliente) tiene 2 valores únicos: "Female" y "Male"<br>
# ▶ La Serie "SeniorCitizen" (clientes que son ciudadanos senior) tiene 2 valores únicos: "0" y "1"<br>
# ▶ La Serie "Partner" (indicador de si el cliente tiene pareja) tiene 2 valores únicos: "Yes" y "No"<br>
# ▶ La Serie "Dependents" (clientes con dependientes) tiene 2 valores únicos: "No" y "Yes"<br>
#
# *Más adelante será necesario el tratamiento de las variables categóricas en una forma numérica que los algoritmos de aprendizaje automático puedan procesar de manera efectiva.
# </div>

# %% [markdown]
# ##### DataFrame Internet

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Se muestra la información sobre los servicios de internet
# </div>

# %%
# General Dataframe properties
df_internet.info()
display(df_internet.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# ...

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Valores únicos para las Series y entendimiento de los datos que manejan
# </div>

# %%
# Number of values
nunique_internet = df_internet['InternetService'].nunique()
nunique_security = df_internet['OnlineSecurity'].nunique()
nunique_backup = df_internet['OnlineBackup'].nunique()
nunique_protection = df_internet['DeviceProtection'].nunique()
nunique_tech = df_internet['TechSupport'].nunique()
nunique_tv = df_internet['StreamingTV'].nunique()
nunique_movies = df_internet['StreamingMovies'].nunique()

# Unique values
values_internet = df_internet['InternetService'].unique()
values_security = df_internet['OnlineSecurity'].unique()
values_backup = df_internet['OnlineBackup'].unique()
values_protection = df_internet['DeviceProtection'].unique()
values_tech = df_internet['TechSupport'].unique()
values_tv = df_internet['StreamingTV'].unique()
values_movies = df_internet['StreamingMovies'].unique()

# ------------------------------------------------------------------------------#

# Print "InternetService" number & values
print(f"Número de valores únicos en la columna 'InternetService': {
      nunique_internet}")
for value in values_internet:
    print(value)

print()

# Print "OnlineSecurity" number & values
print(f"Número de valores únicos en la columna 'OnlineSecurity': {
      nunique_security}")
for value in values_security:
    print(value)

print()

# Print "OnlineBackup" number & values
print(f"Número de valores únicos en la columna 'OnlineBackup': {
      nunique_backup}")
for value in values_backup:
    print(value)

print()

# Print "DeviceProtection" number & values
print(f"Número de valores únicos en la columna 'DeviceProtection': {
      nunique_protection}")
for value in values_protection:
    print(value)

print()

# Print "TechSupport" number & values
print(f"Número de valores únicos en la columna 'TechSupport': {nunique_tech}")
for value in values_tech:
    print(value)

print()

# Print "StreamingTV" number & values
print(f"Número de valores únicos en la columna 'StreamingTV': {nunique_tv}")
for value in values_tv:
    print(value)

print()

# Print "StreamingMovies" number & values
print(f"Número de valores únicos en la columna 'StreamingMovies': {nunique_movies}")
for value in values_movies:
    print(value)

print()
# Out:
# Número de valores únicos en la columna 'InternetService': 2
# DSL
# Fiber optic
#
# Número de valores únicos en la columna 'OnlineSecurity': 2
# No
# Yes
#
# Número de valores únicos en la columna 'OnlineBackup': 2
# Yes
# No
#
# Número de valores únicos en la columna 'DeviceProtection': 2
# No
# Yes
#
# Número de valores únicos en la columna 'TechSupport': 2
# No
# Yes
#
# Número de valores únicos en la columna 'StreamingTV': 2
# No
# Yes
#
# Número de valores únicos en la columna 'StreamingMovies': 2
# No
# Yes

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Observaciones iniciales:</b><br>
# ▶ No se observan valores ausentes<br>
# ▶ Los nombres de las Series están en mayúsculas y minúsculas, se sugiere convertir todo a minúsculas para trabajar más cómodamente y tener consistencia en los datos<br>
# ▶ Nuevamente la Serie "customerID" como identificador de cada cliente<br>
# ▶ La Serie "InternetService" (tipo de servicio de Internet) tiene 2 valores únicos: "DSL" y "Fiber optic"<br>
# ▶ La Serie "OnlineSecurity" (servicio de seguridad) tiene 2 valores únicos: "No" y "Yes"<br>
# ▶ La Serie "OnlineBackup" (servicio de seguridad) tiene 2 valores únicos: "No" y "Yes"<br>
# ▶ La Serie "DeviceProtection" (servicio de seguridad) tiene 2 valores únicos: "No" y "Yes"<br>
# ▶ La Serie "TechSupport" (servicio de soporte) tiene 2 valores únicos: "No" y "Yes"<br>
# ▶ La Serie "StreamingTV" (servicio de streaming de televisión) tiene 2 valores únicos: "No" y "Yes"<br>
# ▶ La Serie "StreamingMovies" (servicio de streaming de películas) tiene 2 valores únicos: "No" y "Yes"<br>
#
# *Más adelante será necesario el tratamiento de las variables categóricas en una forma numérica que los algoritmos de aprendizaje automático puedan procesar de manera efectiva.
# </div>

# %% [markdown]
# ##### DataFrame Phone

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Se muestran datos sobre los servicios telefónicos
# </div>

# %%
# General Dataframe properties
df_phone.info()
display(df_phone.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Valores únicos para las Series y entendimiento de los datos que manejan
# </div>

# %%
# Number of values
nunique_lines = df_phone['MultipleLines'].nunique()

# Unique values
values_lines = df_phone['MultipleLines'].unique()

# ------------------------------------------------------------------------------#

# Print "MultipleLines" number & values
print(f"Número de valores únicos en la columna 'MultipleLines': {
      nunique_lines}")
for value in values_lines:
    print(value)

print()
# Out:
# Número de valores únicos en la columna 'MultipleLines': 2
# No
# Yes

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Observaciones iniciales:</b><br>
# ▶ No se observan valores ausentes<br>
# ▶ Los nombres de las Series están en mayúsculas y minúsculas, se sugiere convertir todo a minúsculas para trabajar más cómodamente y tener consistencia en los datos<br>
# ▶ Nuevamente la Serie "customerID" como identificador de cada cliente<br>
# ▶ La Serie "MultipleLines" (indicador de si el cliente tiene múltiples líneas telefónicas) tiene 2 valores únicos: "No" y "Yes"<br>
#
# *Más adelante será necesario el tratamiento de las variables categóricas en una forma numérica que los algoritmos de aprendizaje automático puedan procesar de manera efectiva.
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Análisis Exploratorio de Datos (EDA)

# %% [markdown]
# ### Combinación de DataFrames

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ A continuación se combinan todos los conjuntos de datos para juntar información sobre contratos de servicios para clientes. <br>
# ▶ Se utiliza "outer" en las operaciones de fusión "merge" para garantizar que solo se conserven todas las filas en todas las tablas de datos que se están fusionando.
# </div>

# %%
# DataFrames merge
df_merged = pd.merge(df_contract, df_personal, on='customerID', how='outer')
df_merged = pd.merge(df_merged, df_internet, on='customerID', how='outer')
df_merged = pd.merge(df_merged, df_phone, on='customerID', how='outer')

# Shape
print("Número de filas y columnas para DataFrame combinado:")
print(df_merged.shape)

# Print
df_merged.info()
display(df_merged.head())
# Out:
# Número de filas y columnas para DataFrame combinado:
# (7043, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  InternetService   5517 non-null   object
#  13  OnlineSecurity    5517 non-null   object
#  14  OnlineBackup      5517 non-null   object
# ...

# %% [markdown]
# ### Limpieza de datos

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ A continuación se convierten todos los nombres de las columnas del DataFrame df_merged a minúsculas, de esta forma se mantiene consistencia en todo el código y se evitan posibles errores al referenciar columnas.
# </div>

# %%
# Convert to lowercase
df_merged.columns = df_merged.columns.str.lower()

# Print
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   begindate         7043 non-null   object
#  2   enddate           7043 non-null   object
#  3   type              7043 non-null   object
#  4   paperlessbilling  7043 non-null   object
#  5   paymentmethod     7043 non-null   object
#  6   monthlycharges    7043 non-null   float64
#  7   totalcharges      7043 non-null   object
#  8   gender            7043 non-null   object
#  9   seniorcitizen     7043 non-null   int64
#  10  partner           7043 non-null   object
#  11  dependents        7043 non-null   object
#  12  internetservice   5517 non-null   object
#  13  onlinesecurity    5517 non-null   object
#  14  onlinebackup      5517 non-null   object
#  15  deviceprotection  5517 non-null   object
# ...

# %% [markdown]
# ### Tipos de datos

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Para facilitar el análisis de fechas en el conjunto de datos, se cambia el tipo de datos de dos columnas en el DataFrame: "begindate" y "enddate" (primero reemplaza los valores "No" por valores nulos). <br>
# ▶ La Serie "totalcharges" debe cambiar de object a tipo numérico
# </div>

# %%
# Change data type
df_merged['begindate'] = pd.to_datetime(df_merged['begindate'])

# %%
# Convert 'No' en NaN
df_merged['enddate'] = df_merged['enddate'].replace('No', np.nan)

# Change data tpye
df_merged['enddate'] = pd.to_datetime(df_merged['enddate'])

# %%
# Convert 'totalcharges' to numeric
df_merged['totalcharges'] = pd.to_numeric(df_merged['totalcharges'], errors='coerce')

# %%
# Delete NaN values for Dataframe on 'totalcharges'
df_merged = df_merged.dropna(subset=['totalcharges'])

# DataFrame properties
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7032 non-null   object
#  1   begindate         7032 non-null   datetime64[ns]
#  2   enddate           1869 non-null   datetime64[ns]
#  3   type              7032 non-null   object
#  4   paperlessbilling  7032 non-null   object
#  5   paymentmethod     7032 non-null   object
#  6   monthlycharges    7032 non-null   float64
#  7   totalcharges      7032 non-null   float64
#  8   gender            7032 non-null   object
#  9   seniorcitizen     7032 non-null   int64
#  10  partner           7032 non-null   object
#  11  dependents        7032 non-null   object
#  12  internetservice   5512 non-null   object
#  13  onlinesecurity    5512 non-null   object
#  14  onlinebackup      5512 non-null   object
#  15  deviceprotection  5512 non-null   object
# ...

# %% [markdown]
# ### Estadística descriptiva

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ La estadísticas descriptivas básicas proporciona un resumen rápido y útil de los datos numéricos presentes en "df_merged", ayudando a entender las características generales de los datos.<br>
# ▶ Se observa que las fechas de inicio de contrato van de 2013 a 2020, mientras que las de fin de contrato se concentran en 2019 y 2020<br>
# </div>

# %%
# Descriptive statistics
df_merged.describe()
# Out:
#                            begindate                        enddate  \
# count                           7032                           1869
# mean   2017-04-28 23:14:44.641638400  2019-11-15 21:31:18.009630976
# min              2013-10-01 00:00:00            2019-10-01 00:00:00
# 25%              2015-06-01 00:00:00            2019-11-01 00:00:00
# 50%              2017-09-01 00:00:00            2019-11-01 00:00:00
# 75%              2019-04-01 00:00:00            2019-12-01 00:00:00
# max              2020-01-01 00:00:00            2020-01-01 00:00:00
# std                              NaN                            NaN
#
#        monthlycharges  totalcharges  seniorcitizen
# count     7032.000000   7032.000000    7032.000000
# mean        64.798208   2283.300441       0.162400
# min         18.250000     18.800000       0.000000
# 25%         35.587500    401.450000       0.000000
# 50%         70.350000   1397.475000       0.000000
# ...

# %% [markdown]
# ### Proporción de contratos activos e inactivos

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Para identificar y contar los contratos que están activos en el conjunto de datos, se seleccionan todos los registros en "df_merged" donde la columna "enddate" cuenta con una fecha de finalización de contrato.<br>
# ▶ Esta separación en los datos serán la base de una parte importante en las exploraciones y análisis iniciales para este proyecto.
# </div>

# %%
# Active contracts
active_contracts = df_merged[df_merged['enddate'].isnull()]
count_active_contracts = active_contracts.shape[0]

# Closed contracts
finished_contracts = df_merged[df_merged['enddate'].notna()]
count_finished_contracts = finished_contracts.shape[0]

# %%
# Graph size
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Subplot 1: Count contracts
sns.barplot(x=['Activos', 'No activos'], y=[
            count_active_contracts, count_finished_contracts], ax=axs[0])

# Title
axs[0].set_title('Cantidad de contratos activos e inactivos')
axs[0].set_xlabel('Estado del contrato')
axs[0].set_ylabel('Cantidad de contratos')

# Count annotations
for p in axs[0].patches:
    axs[0].annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -20), textcoords='offset points', fontsize=10)

# Subplot 2: Percentage contracts
labels = ['Activos', 'No activos']
sizes = [count_active_contracts, count_finished_contracts]
colors = ['lightgreen', 'gray']
explode = (0.1, 0)  # Definir explode para resaltar la primera porción

# Pie chart
axs[1].pie(sizes, explode=explode, labels=labels, colors=colors,
           autopct='%1.1f%%', shadow=True, startangle=140)

# Title
axs[1].set_title('Proporción de contratos activos e inactivos')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Para comparar visualmente la proporción de contratos activos e inactivos, arriba se muestran una gráfica de barras con la representación absoluta y un pastel para su proporción relativa al total de contratos.<br>
# ▶ Se observa que la mayoría de los contratos están activos, representando aproximadamente el 73% del total. Entender esta distribución es importante para desarrollar estrategias de retención de clientes.
# </div>

# %% [markdown]
# ### Evolución de los contratos en el tiempo

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Dividir los datos en contratos activos y contratos inactivos (o finalizados) y realizar un conteo para cada año, permite entender cómo varía la cantidad de contratos a lo largo del tiempo.
# </div>

# %%
# Active contracts
active_contracts = df_merged[df_merged['enddate'].isnull()]

# Inactive contracts
finished_contracts = df_merged[df_merged['enddate'].notna()]

# Sorted years
years = sorted(df_merged['begindate'].dt.year.unique())

# Counters initialization
active_counts = []
finished_counts = []

# Loop
for year in years:
    # Active new contracts
    active_year = active_contracts[active_contracts['begindate'].dt.year == year].shape[0]

    # Finished contracts
    finished_year = finished_contracts[finished_contracts['enddate'].dt.year == year].shape[0]

    # Append
    active_counts.append(active_year)
    finished_counts.append(finished_year)

# Print
print(active_counts)
print(finished_counts)
# Out:
# [0, 1246, 729, 618, 646, 715, 976, 233]
# [0, 0, 0, 0, 0, 0, 1409, 460]

# %%
# Graph size and configuration
bar_width = 0.35
index = np.arange(len(years))
plt.figure(figsize=(12, 6))

# Active and finished contracts bars
bars1 = plt.bar(index - bar_width/2, active_counts, bar_width,
                label='Contratos activos', color='green', alpha=0.7)
bars2 = plt.bar(index + bar_width/2, finished_counts, bar_width,
                label='Contratos no activos', color='gray', alpha=0.7)

# Title
plt.title('Conteo de contratos activos y no activos por año')
plt.xlabel('Año')
plt.ylabel('Cantidad de contratos')
plt.xticks(index, years)  # X axis labels
plt.legend()

# Count
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        if height != 0: #Count only if the value is different from 0
            plt.gca().annotate(format(height, '.0f'),
                               (bar.get_x() + bar.get_width() / 2., height),
                               ha='center', va='center', xytext=(0, -20),
                               textcoords='offset points', fontsize=10)

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Los Contratos Nuevos Activos comienzan con 0 en el primer año, aumenta considerablemente en el segundo año (1246) y luego disminuye gradualmente en los años siguientes. Hay un ligero aumento a partir del quinto año (646) y hasta el séptimo (976), pero vuelve a disminuir drásticamente en el octavo y último año de los datos (244).<br>
# ▶ Por otro lado los Contratos Inactivos/Cancelaciones durante los primeros seis años, no tiene registros, lo que indica una retención completa durante ese período. Sin embargo a partir del séptimo año, se observa un aumento significativo en los contratos inactivos o cancelaciones, con 1409 registros y 460 en el octavo año.<br>
# ▶ El entendimiento de estas fluctuaciones ayuda a identificar posibles cambios en la adquisición de nuevos clientes o en la retención de clientes existentes a lo largo de los años. El aumento repentino en las cancelaciones en el séptimo año puede deberse a varios factores, como insatisfacción del cliente, cambios en el mercado o competencia.
# </div>

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# <div style="color: #196CC4;">
# <b><u>Contratos activos</u></b><br>
#
# ▶ A continuación nos basamos en la presencia de valores NaN en la columna 'enddate', para crear una columna adicional 'contract_active' que represente el estado activo o no del contrato, facilitando análisis posteriores y la construcción de modelos predictivos.<br>
# ▶ Esta nueva Serie puede ser la nueva característica objetivo con dos únicos valores para contratos activos e inactivos ('Yes' y 'No'), para poder mantener la columna 'enddate' como tipo date y conservar todos sus valores de fechas.
# </div>

# %%
# New Series
df_merged['contract_active'] = df_merged['enddate'].isnull()

# Print
display(df_merged.head())
# Out:
#    customerid  begindate    enddate            type paperlessbilling  \
# 0  0002-ORFBO 2019-05-01        NaT        One year              Yes
# 1  0003-MKNFE 2019-05-01        NaT  Month-to-month               No
# 2  0004-TLHLJ 2019-09-01 2020-01-01  Month-to-month              Yes
# 3  0011-IGKFF 2018-12-01 2020-01-01  Month-to-month              Yes
# 4  0013-EXCHZ 2019-09-01 2019-12-01  Month-to-month              Yes
#
#       paymentmethod  monthlycharges  totalcharges  gender  seniorcitizen  ...  \
# 0      Mailed check            65.6        593.30  Female              0  ...
# 1      Mailed check            59.9        542.40    Male              0  ...
# 2  Electronic check            73.9        280.85    Male              0  ...
# 3  Electronic check            98.0       1237.85    Male              1  ...
# 4      Mailed check            83.9        267.40  Female              1  ...
#
#   dependents internetservice onlinesecurity onlinebackup deviceprotection  \
# ...

# %% [markdown]
# <div style="color: #196CC4;">
# <b><u>Duración de los contratos</u></b><br>
#
# ▶ Se crea una nueva Serie "duration_days" a partir de los datos existentes para facilitar el análisis de aquellos contratos que han sido finalizados.<br>
# ▶ Calcular y visualizar la duración de los contratos finalizados en días, proporciona información útil para analizar la distribución y características de estos contratos en el tiempo.
# </div>

# %%
# New DataFrame
contracts_dates = df_merged[['begindate', 'enddate']].copy()

# New Series
df_merged['duration_days'] = (contracts_dates['enddate'] - contracts_dates['begindate']).dt.days.astype('Int64')

# Print
display(df_merged[['begindate', 'enddate', 'duration_days']].head(5))
# Out:
#    begindate    enddate  duration_days
# 0 2019-05-01        NaT           <NA>
# 1 2019-05-01        NaT           <NA>
# 2 2019-09-01 2020-01-01            122
# 3 2018-12-01 2020-01-01            396
# 4 2019-09-01 2019-12-01             91

# %% [markdown]
# <div style="color: #196CC4;">
# <b><u>Distribución de la duración de contratos</u></b><br>
#
# ▶ La estadística descriptiva proporciona información valiosa sobre la duración de los contratos.<br>
# ▶ El diagrama de caja ofrece una visualización gráfica de la distribución de los datos.
# </div>

# %%
df_merged['duration_days'].describe()
# Out:
# count        1869.0
# mean      547.35206
# std      594.389607
# min            30.0
# 25%            61.0
# 50%           304.0
# 75%           883.0
# max          2191.0
# Name: duration_days, dtype: Float64

# %%
# Copy of finished contracts
finished_contracts = df_merged[df_merged['enddate'].notna()].copy()

# Duration days for finished contracts
finished_contracts['duration_days'] = (
    finished_contracts['enddate'] - finished_contracts['begindate']).dt.days

# Plot
plt.figure(figsize=(10, 4))

# Boxplot
sns.boxplot(x='duration_days', data=finished_contracts,
            color='skyblue')
plt.xlabel('Duración (días)')
plt.title('Distribución de duración de contratos finalizados')
plt.grid(True)

# Key datapoints
desc_stats = finished_contracts['duration_days'].describe()
stats_str = f'Mediana: {desc_stats["50%"]}\nQ1: {desc_stats["25%"]}\nQ3: {
    desc_stats["75%"]}\nMin: {desc_stats["min"]}\nMax: {desc_stats["max"]}'

plt.annotate(stats_str,
             xy=(0.95, 0.5),
             xycoords='axes fraction',
             xytext=(-10, 0),
             textcoords='offset points',
             ha='right', va='center',
             fontsize=10,
             bbox=dict(boxstyle='round,pad=0.5', fc='lightyellow', alpha=0.7))

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Hay un total de 1,869 contratos finalizados.<br>
# ▶ La duración promedio de estos contratos es de aproximadamente 547 días.<br>
# ▶ La mayoría de los contratos tienen una duración concentrada entre aproximadamente 61 y 883 días, como indica el rango intercuartílico (25%: 61 días | 50%: 304 días | 75%: 883 días).<br>
# ▶ La variabilidad de la duración de los contratos tiene una desviación estándar de aproximadamente 549 días.<br>
# ▶ El contrato más corto tiene una duración de 30 días, mientras que el más largo tiene una duración de 2,191 días, por lo que hay un amplio rango de valores atípicos hacia la duración máxima<br>
# </div>

# %% [markdown]
# ### Características del servicio de internet

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Para analizar los resultados de los servicios y entender los patrones de comportamiento entre los usuarios que cancelan su contrato y los que mantienen contratos activos, vamos a examinar cada uno a continuación
# </div>

# %%
# Categories
categories = ['onlinesecurity', 'onlinebackup', 'deviceprotection',
              'techsupport', 'streamingtv', 'streamingmovies', 'paperlessbilling', 'multiplelines', 'internetservice']

# Color palette
custom_palette = {'No': 'gray', 'Yes': 'lightgreen',
                  'Fiber optic': 'skyblue', 'DSL': 'skyblue'}

# Graph size
plt.figure(figsize=(14, 20))

# Loop
for i, category in enumerate(categories, 1):
    # Active contracts subplot
    plt.subplot(len(categories), 2, 2*i - 1)
    ax = sns.countplot(x=category, data=active_contracts,
                       hue=category, palette=custom_palette)
    
    # Title
    plt.title(f'Contratos activos - {category}')
    #plt.xlabel(category)
    plt.ylabel('Cantidad')

    # Count
    for p in ax.patches:
        ax.annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -15),
                    textcoords='offset points', fontsize=12)

    # Inactive contracts subplot
    plt.subplot(len(categories), 2, 2*i)
    ax = sns.countplot(x=category, data=finished_contracts,
                       hue=category, palette=custom_palette)
    
    # Title
    plt.title(f'Contratos no activos - {category}')
    #plt.xlabel(category)
    plt.ylabel('Cantidad')

    # Count
    for p in ax.patches:
        ax.annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -15),
                    textcoords='offset points', fontsize=12)

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ <b>Online Security:</b> tanto los contratos activos como no activos tienden a tener menos seguridad en línea, peo es drásticamente más pronunciado en los no activos, por lo que la falta de seguridad en línea puede ser un factor que influye en la cancelación de contratos.<br>
# ▶ <b>Online Backup:</b> los contratos activos tienen más respaldo en línea que los contratos no activos, por lo que este servicio puede ser otro factor de retención.<br>
# ▶ <b>Device Protection:</b> al igual que en los dos servicios previos, los contratos activos tienen más protección de dispositivos que los contratos no activos.<br>
# ▶ <b>Tech Support:</b> tanto los usuarios activos como los no activos tienden a tener menos acceso a soporte técnico, pero en los contratos no activos la diferencia es mucho más drástica; esto sugiere que un buen soporte técnico puede ser crucial para la retención de clientes.<br>
# ▶ <b>Streaming TV y Streaming Movies:</b>Ambos servicios de streaming muestran patrones donde los contratos activos tienen números más altos de acceso a estos servicios en comparación con los contratos no activos, por lo que los servicios de entretenimiento puede influir positivamente en la retención de clientes.<br>
# ▶ <b>Paperless Billing:</b>La facturación electrónica parece ser más común entre los contratos activos y no activos, aunque en los contratos no activos la diferencia es mucho mayor.<br>
# ▶ <b>Multiple Lines:</b>La presencia de múltiples líneas es menos común  en contratos activos que en los no activos, donde la proporción está prácticamente equilibrada.<br>
# ▶ <b>Internet Service:</b> Fiber Optic es menos predominante en los contratos activos en comparación con DSL. Hay una proporción considerable de contratos no activos que utilizaban Fiber Optic en comparación con DSL, lo que podría estar relacionado con la cancelación de contratos.<br>
#
# </div>

# %% [markdown]
# ### Características de los clientes

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Para entender los patrones de comportamiento de los usuarios que cancelan su contrato y los que mantienen contratos activos, vamos a examinar cada una de sus características a continuación
# </div>

# %%
# Categories
categories = ['gender', 'seniorcitizen', 'partner', 'dependents']

# Color palette
custom_palette = {'No': 'gray', 'Yes': 'lightgreen', 0: 'gray',
                  1: 'lightgreen', 'Male': 'skyblue', 'Female': 'pink'}

# Graph size
plt.figure(figsize=(14, 13))

# Loop
for i, category in enumerate(categories, 1):
    # Active contracts subplot
    plt.subplot(len(categories), 2, 2*i - 1)
    ax = sns.countplot(x=category, data=active_contracts,
                       # Ensure the order is the same
                       order=sorted(active_contracts[category].unique()),
                       hue=category, palette=custom_palette)

    # Title
    plt.title(f'Contratos activos - {category}')
    plt.xlabel(category)
    plt.ylabel('Cantidad')

    # Count annotations
    for p in ax.patches:
        if p.get_height() > 0:
            ax.annotate(format(p.get_height(), '.0f'),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center', xytext=(0, -15),
                        textcoords='offset points', fontsize=12)

    # Inactive contracts subplot
    plt.subplot(len(categories), 2, 2*i)
    ax = sns.countplot(x=category, data=finished_contracts,
                       # Ensure the order is the same
                       order=sorted(finished_contracts[category].unique()),
                       hue=category, palette=custom_palette)

    # Title
    plt.title(f'Contratos no activos - {category}')
    plt.xlabel(category)
    plt.ylabel('Cantidad')

    # Count annotations
    for p in ax.patches:
        if p.get_height() > 0:
            ax.annotate(format(p.get_height(), '.0f'),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center', xytext=(0, -15),
                        textcoords='offset points', fontsize=12)

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ <b>Gender:</b> No hay una diferencia significativa en términos de género entre los contratos activos y no activos.<br>
# ▶ <b>Senior Citizen:</b> Los ciudadanos mayores tienen una proporción menor tanto en contratos activos como no activos. Por otro lado, a pesar de seguir siendo minoría, la proporción de ciudadanos mayores parece ser ligeramente mayor entre los contratos activos.<br>
# ▶ <b>Partner:</b> Los clientes que tienen pareja tienden a tener una proporción más alta de contratos activos en comparación con aquellos que no tienen pareja, lo cual podría tener un efecto positivo en la retención de contratos activos.<br>
# ▶ <b>Dependents:</b> a pesar de que los clientes con dependientes son minoría en ambos casos, estos usuarios tienen una proporción más alta en contratos activos en comparación con los contratos inactivos.<br>
# </div>

# %% [markdown]
# ### Tipos de contrataciones y cargos

# %% [markdown]
# <div style="color: #196CC4;">
#
# ▶ De acuerdo a los datos sobre los tipos de contrato y los cargos mensuales para contratos activos y no activos, podemos identificar algunos patrones y características a continuación
# </div>

# %%
# Contract type
order = ['Month-to-month', 'One year', 'Two year']

# Graph size
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(18, 10))

# Subplot 1: Monthly charges & Active contracts
sns.boxplot(x='type', y='monthlycharges', data=active_contracts,
            palette='Set3', hue='type', ax=axs[0, 0], order=order)
axs[0, 0].set_title('Cargos mensuales para contratos activos')
axs[0, 0].set_xlabel('Tipo de contrato')
axs[0, 0].set_ylabel('Cargos mensuales')

# Subplot 2: Monthly charges & Inactive contracts
sns.boxplot(x='type', y='monthlycharges', data=finished_contracts,
            palette='Set3', hue='type', ax=axs[0, 1], order=order)
axs[0, 1].set_title('Cargos mensuales para contratos no activos')
axs[0, 1].set_xlabel('Tipo de contrato')
axs[0, 1].set_ylabel('Cargos mensuales')

# Subplot 3: Contract type & Active contracts
sns.countplot(x='type', data=active_contracts,
              palette='Set2', hue='type', ax=axs[1, 0], order=order)
axs[1, 0].set_title('Distribución de tipos de contrato para contratos activos')
axs[1, 0].set_xlabel('Tipo de contrato')
axs[1, 0].set_ylabel('Cantidad')

# Subplot 4: Contract type & Inactive contracts
sns.countplot(x='type', data=finished_contracts,
              palette='Set2', hue='type', ax=axs[1, 1], order=order)
axs[1, 1].set_title(
    'Distribución de tipos de contrato para contratos no activos')
axs[1, 1].set_xlabel('Tipo de contrato')
axs[1, 1].set_ylabel('Cantidad')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Cargos Mensuales por Tipo de Contrato</b><br>
# ▶ <b>"Month-to-Month":</b> estos contratos tienden a tener cargos mensuales más bajos para no activos.<br>
# ▶ <b>"Two Year":</b> especialmente para contratos no activos, muestran una mediana de cargos mensuales más alta, mientras que el rango intercuartílico es mayor para los contratos activos. Se observa que los clientes que optan por cancelar su contrato tienen tarifas más altas, mientras que los usuarios con contratos que permanecen tienen preferencia por tarifas mensuales más accesibles y son menos propensos a cancelar.<br>
#
# <b>Distribución de Tipo de Contrato</b><br>
# ▶ <b>Contratos activos:</b> "Month-to-month" es el tipo de contrato más común entre los contratos activos; esto sugiere que la mayoría de los clientes prefieren contratos mensuales y con ello flexibilidad, en lugar de compromisos a largo plazo.<br>
# ▶ <b>Contratos no activos:</b> "Month-to-month" también es el tipo de contrato más común entre los contratos no activos. La proporción de clientes que cancelan con un esquema de contrato "One year" o "Two year" es considerablemente menor en comparación con la proporción de estos mismos esquemas en los contratos activos.<br>
# ▶ <b>Resumen:</b> la mayoría de los clientes buscan contratos "Month-to-month", lo cual representa flexibilidad y en consecuencia una alta tasa de rotación o cancelación. De manera contrastante, los clientes con contratos de "One year" o "Two year" buscan más una afiliación a largo plazo en su gran mayoría ya que tienen una taza de cancelación mínima.<br>
# </div>

# %% [markdown]
# ### Métodos de pago

# %% [markdown]
# <div style="color: #196CC4;">
#
# ▶ Basado en la distribución de métodos de pago para contratos activos y no activos, podemos observar lo siguiente:
# </div>

# %%
# Definir el orden de los métodos de pago
payment_order = df_merged['paymentmethod'].value_counts().index

# Tamaño del gráfico y configuración del grid
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

# Subplot 1: Métodos de pago para contratos activos
sns.countplot(x='paymentmethod', data=active_contracts,
              palette='Set2', hue='paymentmethod', ax=axs[0], order=payment_order)
axs[0].set_title('Métodos de pago para contratos activos')
axs[0].set_xlabel('Método de pago')
axs[0].set_ylabel('Conteo')

# Girar etiquetas del eje x
axs[0].tick_params(axis='x', rotation=45)

# Anotaciones en el countplot de contratos activos
for p in axs[0].patches:
    axs[0].annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -10),
                    textcoords='offset points', fontsize=12)

# Subplot 2: Métodos de pago para contratos no activos
sns.countplot(x='paymentmethod', data=finished_contracts,
              palette='Set2', hue='paymentmethod', ax=axs[1], order=payment_order)
axs[1].set_title('Métodos de pago para contratos no activos')
axs[1].set_xlabel('Método de pago')
axs[1].set_ylabel('Conteo')

# Girar etiquetas del eje x
axs[1].tick_params(axis='x', rotation=45)

# Anotaciones en el countplot de contratos no activos
for p in axs[1].patches:
    axs[1].annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -10),
                    textcoords='offset points', fontsize=12)

# Ajuste de diseño y mostrar
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ <b>Equilibrio de contratos activos:</b> tienen una distribución bastante uniforme entre los cuatro métodos de pago, con alrededor de 1290 a 1304 contratos cada uno.<br>
# ▶ <b>Desequilibrio de contratos no activos:</b> muestran una fuerte preferencia hacia el pago por cheque electrónico (1071 contratos), sugiriendo que los clientes que utilizan este método de pago tienen una mayor tendencia a cancelar sus contratos.
#
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Preparación de Datos

# %% [markdown]
# ### Eliminación de datos irrelevantes

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Con base en todo el análisis previo, se puede observar que las siguientes Series no tienen relevancia significativa y por lo tanto podemos precindir de dichos datos para simplificar el procesamiento:</b><br>
#
# ▶ <b>gender:</b> no hay una diferencia significativa en términos de género entre los contratos activos y no activos.<br>
# ▶ <b>begindate:</b> las fechas, por sí solas, no son útiles como entradas directas para la mayoría de los modelos de aprendizaje automático. Es importante simplificar el conjunto de datos a las características más significativas.<br>
# ▶ <b>enddate:</b> al igual que "begindate", este dato no será de utilidad a partir de ahora. La nueva característica objectivo "contract_active" (boolean) ayudará simplificar los resultados de esta investigación.<br>
# ▶ <b>duration_days:</b> extraída de "begindate" y "enddate" fue de utilidad en el análisis exploratorio de datos, sin embargo no se identificaron patrones de temporalidad específicos que puedan influir en los resultados de esta investigación.<br>
# ▶ <b>customerid:</b> inicialmente fue de utilidad para unir todos los conjuntos de datos, pero generalmente no se utiliza como una característica en modelos predictivos directamente, por lo que es mejor eliminarlo.
# </div>

# %%
# Delete Series
df_merged.drop(columns=['gender'], inplace=True)
df_merged.drop(columns=['begindate'], inplace=True)
df_merged.drop(columns=['enddate'], inplace=True)
df_merged.drop(columns=['customerid'], inplace=True)
df_merged.drop(columns=['duration_days'], inplace=True)

# %%
# DataFrame properties
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              7032 non-null   object
#  1   paperlessbilling  7032 non-null   object
#  2   paymentmethod     7032 non-null   object
#  3   monthlycharges    7032 non-null   float64
#  4   totalcharges      7032 non-null   float64
#  5   seniorcitizen     7032 non-null   int64
#  6   partner           7032 non-null   object
#  7   dependents        7032 non-null   object
#  8   internetservice   5512 non-null   object
#  9   onlinesecurity    5512 non-null   object
#  10  onlinebackup      5512 non-null   object
#  11  deviceprotection  5512 non-null   object
#  12  techsupport       5512 non-null   object
#  13  streamingtv       5512 non-null   object
#  14  streamingmovies   5512 non-null   object
#  15  multiplelines     6352 non-null   object
# ...

# %%
# Descriptive statistics
df_merged.describe()
# Out:
#        monthlycharges  totalcharges  seniorcitizen
# count     7032.000000   7032.000000    7032.000000
# mean        64.798208   2283.300441       0.162400
# std         30.085974   2266.771362       0.368844
# min         18.250000     18.800000       0.000000
# 25%         35.587500    401.450000       0.000000
# 50%         70.350000   1397.475000       0.000000
# 75%         89.862500   3794.737500       0.000000
# max        118.750000   8684.800000       1.000000

# %% [markdown]
# ### Escalación de datos

# %% [markdown]
# <div style="color: #196CC4;">
# <b>Escalación de datos</b><br>
# ▶ La técnica de escalar datos es comúnmente utilizada en el preprocesamiento de datos para poner todas las características (features) en una misma escala. <br>
# ▶ A continuación se escalan las características 'monthlycharges' y 'totalcharges' en el conjunto de datos, para normalizar características.
# </div>

# %%
# Inicializer
escalador = MinMaxScaler()

# Transformation
df_merged[['monthlycharges', 'totalcharges']] = escalador.fit_transform(
    df_merged[['monthlycharges', 'totalcharges']])

# %%
# Print Series
display(df_merged[['monthlycharges', 'totalcharges']])

# Descriptive statistics
df_merged.describe()
# Out:
#       monthlycharges  totalcharges
# 0           0.471144      0.066294
# 1           0.414428      0.060420
# 2           0.553731      0.030239
# 3           0.793532      0.140670
# 4           0.653234      0.028687
# ...              ...           ...
# 7038        0.367164      0.083556
# 7039        0.665174      0.214043
# 7040        0.318905      0.008533
# 7041        0.493532      0.531831
# 7042        0.405473      0.425664
#
# [7032 rows x 2 columns]
#        monthlycharges  totalcharges  seniorcitizen
# count     7032.000000   7032.000000    7032.000000
# mean         0.463166      0.261309       0.162400
# std          0.299363      0.261571       0.368844
# min          0.000000      0.000000       0.000000
# 25%          0.172512      0.044155       0.000000
# 50%          0.518408      0.159090       0.000000
# 75%          0.712562      0.435719       0.000000
# max          1.000000      1.000000       1.000000

# %% [markdown]
# ### Codificación de variables

# %% [markdown]
# <div style="color: #196CC4;">
# <b>OHE: One-Hot Encoding</b><br>
# ▶ Es fundamental para el preprocesamiento de datos en aprendizaje automático, facilitando la representación y el manejo de variables categóricas en modelos predictivos y analíticos.
# </div>

# %%
# Columns
columns_to_encode = ['internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection',
                     'techsupport', 'streamingtv', 'streamingmovies',
                     'seniorcitizen', 'partner', 'dependents', 'paperlessbilling', 'multiplelines']

# Encode 'type' and 'paymentmethod' without dropping any columns
df_encoded = pd.get_dummies(df_merged, columns=['type', 'paymentmethod'])

# Encode for those with two unique values
df_encoded = pd.get_dummies(
    df_encoded, columns=columns_to_encode, drop_first=True)

# %%
# DataFrame properties
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   monthlycharges                           7032 non-null   float64
#  1   totalcharges                             7032 non-null   float64
#  2   contract_active                          7032 non-null   bool
#  3   type_Month-to-month                      7032 non-null   bool
#  4   type_One year                            7032 non-null   bool
#  5   type_Two year                            7032 non-null   bool
#  6   paymentmethod_Bank transfer (automatic)  7032 non-null   bool
#  7   paymentmethod_Credit card (automatic)    7032 non-null   bool
#  8   paymentmethod_Electronic check           7032 non-null   bool
#  9   paymentmethod_Mailed check               7032 non-null   bool
# ...

# %%
# Display DataFrame
df_encoded.head(5)
# Out:
#    monthlycharges  totalcharges  contract_active  type_Month-to-month  \
# 0        0.471144      0.066294             True                False
# 1        0.414428      0.060420             True                 True
# 2        0.553731      0.030239            False                 True
# 3        0.793532      0.140670            False                 True
# 4        0.653234      0.028687            False                 True
#
#    type_One year  type_Two year  paymentmethod_Bank transfer (automatic)  \
# 0           True          False                                    False
# 1          False          False                                    False
# 2          False          False                                    False
# 3          False          False                                    False
# 4          False          False                                    False
#
#    paymentmethod_Credit card (automatic)  paymentmethod_Electronic check  \
# ...

# %% [markdown]
# ### División de Datos

# %% [markdown]
# <div style="color: #196CC4;">
# <b>A continuación se dividen los datos fuente de la siguiente manera para llegar a una proporción de 6:2:2</b><br>
# ▶ 60% Dataset para entrenamiento<br>
# ▶ 20% Dataset para validación<br>
# ▶ 20% Dataset de prueba<br><br>
#
# Cuanto más grande sea el conjunto de entrenamiento, más datos tendrá el modelo para aprender patrones y relaciones en los datos. Por otro lado el dataset de validación servirá para evaluar el rendimiento del modelo y el dataset de prueba esperará al final para evaluar el rendimiento final del modelo  (cuando haya terminado el proceso de entrenamiento y validación).
# </div>

# %%
# Data split
df_train, remaining_data = train_test_split(df_encoded, test_size=0.4, random_state=12345)
df_valid, df_test = train_test_split(remaining_data, test_size=0.5, random_state=12345)

# %%
# Features and Target variables
features_train = df_train.drop(['contract_active'], axis=1)
target_train = df_train['contract_active']

features_valid = df_valid.drop(['contract_active'], axis=1)
target_valid = df_valid['contract_active']

# FINAL TESTING SETS ↓

# Train + Valid
total_features_train = pd.concat([features_train, features_valid])
total_target_train = pd.concat([target_train, target_valid])

features_test = df_test.drop(['contract_active'], axis=1)
target_test = df_test['contract_active']

# %% [markdown]
# ### Equilibrio de clases

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El análisis del desequilibrio de clases se centra en las etiquetas de la variable objetivo 'contract_active' (boleano) para entender la proporción de cada clase ('True' o 'False'). Este análisis nos permite determinar si hay un desequilibrio significativo en las clases, lo cual es crucial para decidir si necesitamos aplicar técnicas de balanceo como el submuestreo o el sobremuestreo.
# </div>

# %%
# Calculate proportion
class_counts_train = target_train.value_counts(normalize=True)
print("Proporción de clases en el conjunto de entrenamiento:")
print(class_counts_train)

# Graph size
plt.figure(figsize=(4, 3))

# Train data
plt.bar(class_counts_train.index, class_counts_train.values, color=['gray', 'lightgreen'])

# Title
plt.title('Distribución de clases en el conjunto de entrenamiento')
plt.xlabel('Clase')
plt.ylabel('Proporción')
plt.xticks([0, 1], ['False', 'True'])

# Print
plt.tight_layout()
plt.show()
# Out:
# Proporción de clases en el conjunto de entrenamiento:
# contract_active
# True     0.736193
# False    0.263807
# Name: proportion, dtype: float64

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El sobremuestreo y el submuestreo son dos técnicas comunes para abordar el desequilibrio en las clases de un conjunto de datos<br>
# ▶ A continuación se muestra el procedimiento para ambos métodos, ya que cada uno tiene sus beneficios y áreas de oportunidad. Las muestras resultantes serán clave para validar más adelante cuál es de los dos ayuda mejor al rendimiento de los modelos para este proyecto específico.<br>
# ▶ Esto se realiza únicamente en el conjunto de entrenamiento y no es necesario aplicar esto en los conjuntos de validación y prueba, ya que estos conjuntos se utilizan principalmente para evaluar el rendimiento del modelo después de que ha sido entrenado.
# </div>

# %% [markdown]
# #### Sobremuestreo

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Implica aumentar el número de ejemplos en la clase minoritaria para igualar el número de ejemplos en la clase mayoritaria. <br>
# ▶ Con este método no se pierde información del conjunto de datos; además puede ser útil cuando hay suficiente tiempo de procesamiento y cuando la clase minoritaria tiene información valiosa que podría perderse con el submuestreo.<br>
# ▶ Por otro lado puede implicar un mayor tiempo de entrenamiento y puede aumentar el riesgo de sobreajuste.
# </div>

# %%
# Function
def upsample(features, target):
    features_zeros = features[target == False]
    features_ones = features[target == True]
    target_zeros = target[target == False]
    target_ones = target[target == True]

    # Number of repetitions
    repeat_times = len(target_zeros) // len(target_ones)

    # Additional samples
    additional_samples = len(target_zeros) % len(target_ones)

    # Upsample the minority class
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat_times + [
                                   features_ones.sample(additional_samples, replace=True)])
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat_times + [
                                 target_ones.sample(additional_samples, replace=True)])

    # Shuffle data
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)

    # Return
    return features_upsampled, target_upsampled

# Apply upsampling
features_upsampled, target_upsampled = upsample(features_train, target_train)

# %%
# Calculate distribution
class_frequency_upsampled = target_upsampled.value_counts(normalize=True)

# Print
print("Distribución de clases después de sobremuestreo:")
print(class_frequency_upsampled)

# Graph size
plt.figure(figsize=(4, 3))

# Plot
class_frequency_upsampled.plot(kind='bar', color=['gray', 'lightgreen'])

# Title
plt.title('Distribución de clases después de sobremuestreo')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.xticks([0, 1], ['False', 'True'])

# Print
plt.show()
# Out:
# Distribución de clases después de sobremuestreo:
# contract_active
# False    0.5
# True     0.5
# Name: proportion, dtype: float64

# %% [markdown]
# #### Submuestreo

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Consiste en reducir el número de ejemplos en la clase mayoritaria para igualar la cantidad de ejemplos en la clase minoritaria.<br>
# ▶ Al reducir el tamaño del conjunto de datos, se puede acelerar el entrenamiento del modelo y mejorar su rendimiento al evitar el sobreajuste a la clase mayoritaria.<br>
# ▶ Por otro lado se podría perder información valiosa al eliminar ejemplos de la clase mayoritaria y resultar en un modelo menos preciso.
# </div>

# %%
# Function
def downsample(features, target):

    # Separate characteristics
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

   
    # Submuestrear la clase mayoritaria (1)
    features_majority_downsampled = features_ones.sample(
        len(target_zeros), random_state=12345, replace=False)
    target_majority_downsampled = target_ones.sample(
        len(target_zeros), random_state=12345, replace=False)
    features_minority = features_zeros
    target_minority = target_zeros

    # Downsample the mayority class
    features_downsampled = pd.concat(
        [features_majority_downsampled, features_minority])
    target_downsampled = pd.concat(
        [target_majority_downsampled, target_minority])

    # Shuffle data
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)

    # Return
    return features_downsampled, target_downsampled


# Apply downsampling
features_downsampled, target_downsampled = downsample(
    features_train, target_train)

# %%
# Calculate distribution
class_frequency_downsampled = target_downsampled.value_counts(normalize=True)

# Print
print("Distribución de clases después de submuestreo:")
print(class_frequency_downsampled)

# Graph size
plt.figure(figsize=(4, 3))

# Plot
plt.bar(class_frequency_downsampled.index.astype(str),
        class_frequency_downsampled.values, color=['gray', 'lightgreen'])

# Title
plt.title('Distribución de clases después de submuestreo')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.xticks([0, 1], ['False', 'True'])

# Print
plt.tight_layout()
plt.show()
# Out:
# Distribución de clases después de submuestreo:
# contract_active
# True     0.5
# False    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# -----

# %% [markdown]
# ## Desarrollo del Modelo

# %% [markdown]
# ### Introducción

# %% [markdown]
# <div style="color: #196CC4;">
# <b><u>Modelos</u></b><br>
# Los datos están listos para iniciar con la implementación de los modelos para este proyecto de clasificación:  <br>
# ▶ Regresión Logística<br>
# ▶ KNN Clasifier<br>
# ▶ Random Forest <b>*</b><br>
# ▶ Gradient Boosting Machine (GBM) <b>*</b><br>
# ▶ XGBoost (Extreme Gradient Boosting) <b>*</b><br>
# ▶ LightGBM (Light Gradient Boosting Machine) <b>*</b><br>
# <b>*</b> Se incluye variación con validación cruzada, para verificar si hay mejora en el rendimiento.<br><br>
# <b>Nota:</b> también se valorará si los modelos tienen mejores resultados con los conjuntos de datos del submuestreo o sobremuestreo previamente aplicados.<br><br>
#
# <b><u>Métricas</u></b><br>
# Para este proyecto de clasificación se evualarán los modelos con las siguientes métricas:<br>
# ▶ <b>Accuracy:</b> calcula la proporción de predicciones correctas sobre el total de predicciones realizadas.<br>
# ▶ <b>Precision:</b> es importante para evitar acciones innecesarias de retención en clientes que no cancelarían.<br>
# ▶ <b>Recall:</b> es crucial para identificar la mayor cantidad posible de clientes en riesgo de cancelación.<br>
# ▶ <b>F1-Score:</b> ofrece un equilibrio entre precisión y recall, lo que es esencial para un modelo efectivo.<br>
# ▶ <b>Matriz de Confusión:</b> proporciona una visión detallada del rendimiento del modelo, permitiendo identificar áreas de mejora.<br>
# ▶ <b>AUC-ROC:</b> proporciona una evaluación global del rendimiento del modelo, independientemente del umbral de clasificación.<br>
# </div>

# %% [markdown]
# ### Modelo 1: Regresión Logística

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Es un modelo estadístico sencillo que estima la probabilidad de que ocurra un evento binario. En este proyecto puede ser útil para identificar rápidamente las características más influyentes en la cancelación de contratos.
# </div>

# %%
# Model
model1 = LogisticRegression(random_state=12345, max_iter=1000)

# Fit
#model1.fit(features_upsampled, target_upsampled)
model1.fit(features_downsampled, target_downsampled)

# Predictions
m1_predictions_valid = model1.predict(features_valid)
m1_predictions_proba_valid = model1.predict_proba(features_valid)[:, 1]

# Print
#print(m1_predictions_valid)
#print(m1_predictions_proba_valid)

# %%
# Metrics
m1_auc_roc = roc_auc_score(target_valid, m1_predictions_proba_valid)
m1_accuracy = accuracy_score(target_valid, m1_predictions_valid)
m1_precision = precision_score(target_valid, m1_predictions_valid)
m1_recall = recall_score(target_valid, m1_predictions_valid)
m1_f1 = f1_score(target_valid, m1_predictions_valid)
m1_conf_matrix = confusion_matrix(target_valid, m1_predictions_valid)

# Print metrics
print("\n*****\nModelo 1: Regresión Logística")
print(f"AUC-ROC: {m1_auc_roc:.2f}")
print(f"Accuracy: {m1_accuracy:.2f}")
print(f"Precisión: {m1_precision:.2f}")
print(f"Recall: {m1_recall:.2f}")
print(f"F1 Score: {m1_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m1_conf_matrix)
# Out:
# *****
# Modelo 1: Regresión Logística
# AUC-ROC: 0.83
# Accuracy: 0.74
# Precisión: 0.90
# Recall: 0.72
# F1 Score: 0.80
# Matriz de Confusión:
# [[285  82]
#  [289 750]]

# %%
# General plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6)) 

# Confusion Matrix 
disp = ConfusionMatrixDisplay(confusion_matrix=m1_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (Regresión Logística)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m1_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m1_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (Regresión Logística)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de regresión logística en este proyecto con una mejor combinación de métricas clave como accuracy, recall, F1 score y una matriz de confusión con un menor número de falsos negativos.
# </div>

# %% [markdown]
# ### Modelo 2: KNN Classifier

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Este modelo clasifica a un cliente en función de las características de sus vecinos más cercanos en una medida de similitud. Es un modelo fácil de implementar y puede ser útil para encontrar patrones entre clientes con características similares.
# </div>

# %%
# Model
model2 = KNeighborsClassifier()

# Train
#model2.fit(features_upsampled, target_upsampled)
model2.fit(features_downsampled, target_downsampled)

# Predictions
m2_predictions_valid = model2.predict(features_valid)
m2_predictions_proba_valid = model2.predict_proba(features_valid)[:, 1]
# Out:
# c:\Users\dguez\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\dguez\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")

# %%
# Metrics
m2_auc_roc = roc_auc_score(target_valid, m2_predictions_proba_valid)
m2_accuracy = accuracy_score(target_valid, m2_predictions_valid)
m2_precision = precision_score(target_valid, m2_predictions_valid)
m2_recall = recall_score(target_valid, m2_predictions_valid)
m2_f1 = f1_score(target_valid, m2_predictions_valid)
m2_conf_matrix = confusion_matrix(target_valid, m2_predictions_valid)

# Print
print("\n*****\nModelo 2: K-Nearest Neighbors (KNN) Classifier")
print(f"AUC-ROC: {m2_auc_roc:.2f}")
print(f"Accuracy: {m2_accuracy:.2f}")
print(f"Precisión: {m2_precision:.2f}")
print(f"Recall: {m2_recall:.2f}")
print(f"F1 Score: {m2_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m2_conf_matrix)
# Out:
# *****
# Modelo 2: K-Nearest Neighbors (KNN) Classifier
# AUC-ROC: 0.79
# Accuracy: 0.71
# Precisión: 0.91
# Recall: 0.67
# F1 Score: 0.77
# Matriz de Confusión:
# [[295  72]
#  [341 698]]

# %%
# Plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m2_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (KNN Classifier)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m2_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m2_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (KNN Classifier)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de K-Nearest Neighbors (KNN), ya que ofrece un AUC-ROC y un F1 Score ligeramente superiores, lo que indica que es capaz de discriminar mejor entre las clases y tiene un mejor equilibrio entre precisión y recall en comparación con el conjunto upsampled.
# </div>

# %% [markdown]
# ### Modelo 3: Random Forest

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Construye múltiples árboles de decisión y combina sus resultados para hacer una predicción final. Es robusto y su capacidad para manejar una gran cantidad de variables y descubrir interacciones entre ellas lo hace valioso para identificar patrones complejos de cancelación de clientes.
# </div>

# %%
# Model
model3 = RandomForestClassifier(
    random_state=12345, n_estimators=100, max_depth=10, min_samples_split=10)

# Fit
#model3.fit(features_upsampled, target_upsampled)
model3.fit(features_downsampled, target_downsampled)

# Predictions
m3_predictions_valid = model3.predict(features_valid)
m3_predictions_proba_valid = model3.predict_proba(features_valid)[:, 1]

# %%
# Metrics
m3_auc_roc = roc_auc_score(target_valid, m3_predictions_proba_valid)
m3_accuracy = accuracy_score(target_valid, m3_predictions_valid)
m3_precision = precision_score(target_valid, m3_predictions_valid)
m3_recall = recall_score(target_valid, m3_predictions_valid)
m3_f1 = f1_score(target_valid, m3_predictions_valid)
m3_conf_matrix = confusion_matrix(target_valid, m3_predictions_valid)

# Print metrics
print("\n*****\nModelo 3: Random Forest")
print(f"AUC-ROC: {m3_auc_roc:.2f}")
print(f"Accuracy: {m3_accuracy:.2f}")
print(f"Precisión: {m3_precision:.2f}")
print(f"Recall: {m3_recall:.2f}")
print(f"F1 Score: {m3_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m3_conf_matrix)
# Out:
# *****
# Modelo 3: Random Forest
# AUC-ROC: 0.84
# Accuracy: 0.74
# Precisión: 0.91
# Recall: 0.72
# F1 Score: 0.80
# Matriz de Confusión:
# [[296  71]
#  [293 746]]

# %%
# Plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp_rf = ConfusionMatrixDisplay(confusion_matrix=m3_conf_matrix)
disp_rf.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (Random Forest)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr_rf, tpr_rf, _ = roc_curve(target_valid, m3_predictions_proba_valid)
ax2.plot(fpr_rf, tpr_rf, label='ROC Curve (AUC-ROC=%0.4f)' % m3_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (Random Forest)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de Random Forest. Aunque ambos conjuntos tienen el mismo AUC-ROC, el conjunto downsampled ofrece mejores métricas en términos de accuracy, recall, y F1 Score. Esto indica que el modelo es más equilibrado y efectivo.
# </div>

# %% [markdown]
# ### Modelo 4: Grid Search + Random Forest

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Grid Search optimiza los hiperparámetros del Random Forest buscando la combinación que produce el mejor rendimiento y precisión del modelo.
# </div>

# %%
# Model
model4 = RandomForestClassifier(random_state=12345)

# Parameters
m4_param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [10, 20, 30],
    'min_samples_leaf': [10, 20, 30]
}

# Grid Search configuration
m4_grid_search = GridSearchCV(
    estimator=model4, param_grid=m4_param_grid, cv=5, scoring='f1')

# Train
#m4_grid_search.fit(features_upsampled, target_upsampled)
m4_grid_search.fit(features_downsampled, target_downsampled)

# Best model
m4_best_model = m4_grid_search.best_estimator_

# Predictions
m4_predictions_valid = m4_best_model.predict(features_valid)
m4_predictions_proba_valid = m4_best_model.predict_proba(features_valid)[:, 1]

# Best hyperparameters & score
print("Mejores hiperparámetros:", m4_grid_search.best_params_)
print("Mejor F1:", m4_grid_search.best_score_)
# Out:
# Mejores hiperparámetros: {'max_depth': 20, 'min_samples_leaf': 10, 'n_estimators': 50}
# Mejor F1: 0.744217500163485

# %%
# Metrics
m4_auc_roc = roc_auc_score(target_valid, m4_predictions_proba_valid)
m4_accuracy = accuracy_score(target_valid, m4_predictions_valid)
m4_precision = precision_score(target_valid, m4_predictions_valid)
m4_recall = recall_score(target_valid, m4_predictions_valid)
m4_f1 = f1_score(target_valid, m4_predictions_valid)
m4_conf_matrix = confusion_matrix(target_valid, m4_predictions_valid)

# Print
print("\n*****\nModelo 4: Grid Search + Random Forest")
print(f"AUC-ROC: {m4_auc_roc:.2f}")
print(f"Accuracy: {m4_accuracy:.2f}")
print(f"Precisión: {m4_precision:.2f}")
print(f"Recall: {m4_recall:.2f}")
print(f"F1 Score: {m4_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m4_conf_matrix)
# Out:
# *****
# Modelo 4: Grid Search + Random Forest
# AUC-ROC: 0.84
# Accuracy: 0.73
# Precisión: 0.92
# Recall: 0.70
# F1 Score: 0.79
# Matriz de Confusión:
# [[303  64]
#  [315 724]]

# %%
# Plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m4_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (Grid Search + Random Forest)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m4_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m4_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (Grid Search + Random Forest)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de Grid Search + Random Forest. Tiene un rendimiento ligeramente mejor en términos de métricas clave como F1 Score y la matriz de confusión.
# </div>

# %% [markdown]
# ### Modelo 5: Gradient Boosting Machine (GBM)

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Modelo que construye árboles de decisión de manera secuencial, donde cada nuevo árbol intenta corregir los errores del anterior. Es potente y eficaz para encontrar patrones complejos en los datos, lo que podría ser clave para predecir con precisión la tasa de cancelación de clientes.
# </div>

# %%
# Model
model5 = GradientBoostingClassifier(random_state=12345)

# Train
#model5.fit(features_upsampled, target_upsampled)
model5.fit(features_downsampled, target_downsampled)

# Predictions
m5_predictions_valid = model5.predict(features_valid)
m5_predictions_proba_valid = model5.predict_proba(features_valid)[:, 1]

# %%
# Metrics
m5_auc_roc = roc_auc_score(target_valid, m5_predictions_proba_valid)
m5_accuracy = accuracy_score(target_valid, m5_predictions_valid)
m5_precision = precision_score(target_valid, m5_predictions_valid)
m5_recall = recall_score(target_valid, m5_predictions_valid)
m5_f1 = f1_score(target_valid, m5_predictions_valid)
m5_conf_matrix = confusion_matrix(target_valid, m5_predictions_valid)

# Print
print("\n*****\nModelo 5: Gradient Boosting Machine (GBM)")
print(f"AUC-ROC: {m5_auc_roc:.2f}")
print(f"Accuracy: {m5_accuracy:.2f}")
print(f"Precisión: {m5_precision:.2f}")
print(f"Recall: {m5_recall:.2f}")
print(f"F1 Score: {m5_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m5_conf_matrix)
# Out:
# *****
# Modelo 5: Gradient Boosting Machine (GBM)
# AUC-ROC: 0.84
# Accuracy: 0.74
# Precisión: 0.91
# Recall: 0.71
# F1 Score: 0.80
# Matriz de Confusión:
# [[294  73]
#  [299 740]]

# %%
# General plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m5_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (GBM)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m5_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m5_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (GBM)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de Gradient Boosting Machine (GBM). Aunque el conjunto upsampled tiene un AUC-ROC ligeramente mejor (0.86 vs. 0.85), el conjunto downsampled ofrece mejores métricas en términos de accuracy, recall, y F1 Score.
# </div>

# %% [markdown]
# ### Modelo 6: Grid Search + Gradient Boosting Machine (GBM)

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Grid Search optimiza los hiperparámetros del modelo Gradient Boosting buscando la combinación que maximiza el rendimiento.
# </div>

# %%
# Model
model6 = GradientBoostingClassifier(random_state=12345)

# Parameters
m6_param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_samples_leaf': [10, 20]
}

# Grid Search configuration
m6_grid_search = GridSearchCV(
    estimator=model6, param_grid=m6_param_grid, cv=5, scoring='f1')

# Train with Grid Search
#m6_grid_search.fit(features_upsampled, target_upsampled)
m6_grid_search.fit(features_downsampled, target_downsampled)

# Best model
m6_best_model = m6_grid_search.best_estimator_

# Predictions
m6_predictions_valid = m6_best_model.predict(features_valid)
m6_predictions_proba_valid = m6_best_model.predict_proba(features_valid)[:, 1]

# Best hyperparameters & score
print("Mejores hiperparámetros:", m6_grid_search.best_params_)
print("Mejor F1:", m6_grid_search.best_score_)
# Out:
# Mejores hiperparámetros: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 20, 'n_estimators': 50}
# Mejor F1: 0.7496416886605484

# %%
# Metrics
m6_auc_roc = roc_auc_score(target_valid, m6_predictions_proba_valid)
m6_accuracy = accuracy_score(target_valid, m6_predictions_valid)
m6_precision = precision_score(target_valid, m6_predictions_valid)
m6_recall = recall_score(target_valid, m6_predictions_valid)
m6_f1 = f1_score(target_valid, m6_predictions_valid)
m6_conf_matrix = confusion_matrix(target_valid, m6_predictions_valid)

# Print
print("\n*****\nModelo 6: Grid Search + Gradient Boosting Machine")
print(f"AUC-ROC: {m6_auc_roc:.2f}")
print(f"Accuracy: {m6_accuracy:.2f}")
print(f"Precisión: {m6_precision:.2f}")
print(f"Recall: {m6_recall:.2f}")
print(f"F1 Score: {m6_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m6_conf_matrix)
# Out:
# *****
# Modelo 6: Grid Search + Gradient Boosting Machine
# AUC-ROC: 0.84
# Accuracy: 0.74
# Precisión: 0.92
# Recall: 0.71
# F1 Score: 0.80
# Matriz de Confusión:
# [[302  65]
#  [304 735]]

# %%
# General plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m6_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (Grid Search + Gradient Boosting Machine)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m6_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m6_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (Grid Search + Gradient Boosting Machine)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de Grid Search + Gradient Boosting Machine. Muestra métricas ligeramente superiores en términos de AUC-ROC, exactitud y F1 Score.
# </div>

# %% [markdown]
# ### Modelo 7: XGBoost (Extreme Gradient Boosting)

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Versión mejorada de Gradient Boosting que hace que el modelo sea más rápido y preciso. Es extremadamente eficaz para problemas como la predicción de la cancelación de clientes.
# </div>

# %%
# Set the logging level to ERROR to suppress warnings ("use_label_encoder")
xgb.set_config(verbosity=2)
warnings.filterwarnings('ignore', category=UserWarning, module='xgboost')

# %%
# Convert Arrays of NumPy
features_downsampled_np = features_downsampled.values
target_downsampled_np = target_downsampled.values
features_upsampled_np = features_upsampled.values
target_upsampled_np = target_upsampled.values
features_valid_np = features_valid.values

# Model
model7 = xgb.XGBClassifier(random_state=12345)

# Train
model7.fit(features_downsampled_np, target_downsampled_np)
#model7.fit(features_upsampled_np, target_upsampled_np)

# Predictions
m7_predictions_valid = model7.predict(features_valid_np)
m7_predictions_proba_valid = model7.predict_proba(features_valid_np)[:, 1]

# %%
# Metrics
m7_auc_roc = roc_auc_score(target_valid, m7_predictions_proba_valid)
m7_accuracy = accuracy_score(target_valid, m7_predictions_valid)
m7_precision = precision_score(target_valid, m7_predictions_valid)
m7_recall = recall_score(target_valid, m7_predictions_valid)
m7_f1 = f1_score(target_valid, m7_predictions_valid)
m7_conf_matrix = confusion_matrix(target_valid, m7_predictions_valid)

# Print
print("\n*****\nModelo 7: XGBoost (Extreme Gradient Boosting)")
print(f"AUC-ROC: {m7_auc_roc:.2f}")
print(f"Accuracy: {m7_accuracy:.2f}")
print(f"Precisión: {m7_precision:.2f}")
print(f"Recall: {m7_recall:.2f}")
print(f"F1 Score: {m7_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m7_conf_matrix)
# Out:
# *****
# Modelo 7: XGBoost (Extreme Gradient Boosting)
# AUC-ROC: 0.80
# Accuracy: 0.71
# Precisión: 0.89
# Recall: 0.70
# F1 Score: 0.78
# Matriz de Confusión:
# [[275  92]
#  [316 723]]

# %%
# General plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m7_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (XGBoost)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m7_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m7_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (XGBoost)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de XGBoost. Aunque el conjunto upsampled muestra un AUC-ROC ligeramente mejor (0.83 vs. 0.82) y una precisión un poco más alta, el conjunto downsampled ofrece un mejor accuracy, recall, F1 Score, y una mayor cantidad de verdaderos positivos.
# </div>

# %% [markdown]
# ### Modelo 8: Grid Search + XGBoost (Extreme Gradient Boosting)

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Grid Search ajusta los hiperparámetros del modelo XGBoost para encontrar la configuración que ofrece el mejor rendimiento posible.
# </div>

# %%
# Model
model8 = XGBClassifier(
    random_state=12345, use_label_encoder=False, eval_metric='logloss')

# Parameters
m8_param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5]
}

# Grid Search configuration
m8_grid_search = GridSearchCV(
    estimator=model8, param_grid=m8_param_grid, cv=5, scoring='f1')

# Train GridSearchCV
m8_grid_search.fit(features_downsampled_np, target_downsampled_np)
#m8_grid_search.fit(features_upsampled_np, target_upsampled_np)

# Best model
m8_best_model = m8_grid_search.best_estimator_

# Predictions
m8_predictions_valid = m8_best_model.predict(features_valid_np)
m8_predictions_proba_valid = m8_best_model.predict_proba(features_valid_np)[
    :, 1]

# Best hyperparameters & score
print("Mejores hiperparámetros:", m8_grid_search.best_params_)
print("Mejor F1:", m8_grid_search.best_score_)
# Out:
# Mejores hiperparámetros: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50}
# Mejor F1: 0.7518394976848767

# %%
# Metrics
m8_auc_roc = roc_auc_score(target_valid, m8_predictions_proba_valid)
m8_accuracy = accuracy_score(target_valid, m8_predictions_valid)
m8_precision = precision_score(target_valid, m8_predictions_valid)
m8_recall = recall_score(target_valid, m8_predictions_valid)
m8_f1 = f1_score(target_valid, m8_predictions_valid)
m8_conf_matrix = confusion_matrix(target_valid, m8_predictions_valid)

# Print
print("\n*****\nModelo 8: Grid Search + Extreme Gradient Boosting (XGBoost)")
print(f"AUC-ROC: {m8_auc_roc:.2f}")
print(f"Accuracy: {m8_accuracy:.2f}")
print(f"Precisión: {m8_precision:.2f}")
print(f"Recall: {m8_recall:.2f}")
print(f"F1 Score: {m8_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m8_conf_matrix)
# Out:
# *****
# Modelo 8: Grid Search + Extreme Gradient Boosting (XGBoost)
# AUC-ROC: 0.84
# Accuracy: 0.73
# Precisión: 0.92
# Recall: 0.69
# F1 Score: 0.79
# Matriz de Confusión:
# [[306  61]
#  [320 719]]

# %%
# General plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m8_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (Grid Search + XGBoost)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m8_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m8_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (Grid Search + XGBoost)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de Grid Search + XGBoost. Ofrece un mejor rendimiento en términos de Accuracy, Recall, y F1 Score, lo que es crucial para un balance adecuado entre la identificación correcta de instancias positivas.
# </div>

# %% [markdown]
# ### Modelo 9: LightGBM

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ LightGBM es una variante de Gradient Boosting que está optimizada para la velocidad y la eficiencia en memoria, capaz de manejar grandes volúmenes de datos. Su eficiencia y precisión es ideal para conjuntos de datos grandes
# </div>

# %%
# Model
model9 = lgb.LGBMClassifier(random_state=12345)

# Train
#model9.fit(features_upsampled, target_upsampled)
model9.fit(features_downsampled, target_downsampled)

# Predictions
m9_predictions_valid = model9.predict(features_valid)
m9_predictions_proba_valid = model9.predict_proba(features_valid)[:, 1]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 1113, number of negative: 1113
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000295 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 548
# [LightGBM] [Info] Number of data points in the train set: 2226, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %%
# Metrics
m9_auc_roc = roc_auc_score(target_valid, m9_predictions_proba_valid)
m9_accuracy = accuracy_score(target_valid, m9_predictions_valid)
m9_precision = precision_score(target_valid, m9_predictions_valid)
m9_recall = recall_score(target_valid, m9_predictions_valid)
m9_f1 = f1_score(target_valid, m9_predictions_valid)
m9_conf_matrix = confusion_matrix(target_valid, m9_predictions_valid)

# Print
print("\n*****\nModelo 9: LightGBM (Light Gradient Boosting Machine)")
print(f"AUC-ROC: {m9_auc_roc:.2f}")
print(f"Accuracy: {m9_accuracy:.2f}")
print(f"Precisión: {m9_precision:.2f}")
print(f"Recall: {m9_recall:.2f}")
print(f"F1 Score: {m9_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m9_conf_matrix)
# Out:
# *****
# Modelo 9: LightGBM (Light Gradient Boosting Machine)
# AUC-ROC: 0.82
# Accuracy: 0.72
# Precisión: 0.90
# Recall: 0.70
# F1 Score: 0.79
# Matriz de Confusión:
# [[290  77]
#  [312 727]]

# %%
# General plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m9_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (LightGBM)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m9_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m9_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (LightGBM)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de LightGBM. Aunque ambos conjuntos tienen un AUC-ROC idéntico, el conjunto downsampled ofrece mejores resultados en términos de precisión general (accuracy), recall y F1 Score. Además, tiene un mejor equilibrio entre verdaderos positivos y falsos negativos.
# </div>

# %% [markdown]
# ### Modelo 10: Grid Search + LightGBM

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ La optimización de LightGBM con Grid Search puede llevar al modelo a alcanzar su máximo potencial, incrementando la precisión y maximizando el AUC-ROC.
# </div>

# %%
# Model
model10 = lgb.LGBMClassifier(random_state=12345)

# Parameters
m10_param_grid = {
    'num_leaves': [20, 31],
    'learning_rate': [0.01, 0.1],
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 15]
}

# Grid Search configuration
m10_grid_search = GridSearchCV(
    estimator=model10, param_grid=m10_param_grid, cv=5, scoring='f1')

# Train
#m10_grid_search.fit(features_upsampled, target_upsampled)
m10_grid_search.fit(features_downsampled, target_downsampled)

# Best model
m10_best_model = m10_grid_search.best_estimator_

# Predictions
m10_predictions_valid = m10_best_model.predict(features_valid)
m10_predictions_proba_valid = m10_best_model.predict_proba(features_valid)[:, 1]

# Best hyperparameters
print(f"Mejores hiperparámetros: {m10_grid_search.best_params_}")
print(f"Mejor F1: {m10_grid_search.best_score_:.2f}")
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 890, number of negative: 890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 548
# [LightGBM] [Info] Number of data points in the train set: 1780, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 890, number of negative: 891
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000199 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# ...

# %%
# Metrics
m10_auc_roc = roc_auc_score(target_valid, m10_predictions_proba_valid)
m10_accuracy = accuracy_score(target_valid, m10_predictions_valid)
m10_precision = precision_score(target_valid, m10_predictions_valid)
m10_recall = recall_score(target_valid, m10_predictions_valid)
m10_f1 = f1_score(target_valid, m10_predictions_valid)
m10_conf_matrix = confusion_matrix(target_valid, m10_predictions_valid)

# Print
print("\n*****\nModelo 10: Grid Search + LightGBM")
print(f"AUC-ROC: {m10_auc_roc:.2f}")
print(f"Accuracy: {m10_accuracy:.2f}")
print(f"Precisión: {m10_precision:.2f}")
print(f"Recall: {m10_recall:.2f}")
print(f"F1 Score: {m10_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(m10_conf_matrix)
# Out:
# *****
# Modelo 10: Grid Search + LightGBM
# AUC-ROC: 0.83
# Accuracy: 0.73
# Precisión: 0.91
# Recall: 0.71
# F1 Score: 0.80
# Matriz de Confusión:
# [[294  73]
#  [300 739]]

# %%
# Plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m10_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de Confusión (Grid Search + LightGBM)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m10_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % m10_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (Grid Search + LightGBM)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El conjunto de datos <b>"downsampled"</b> es el mejor para este modelo de Grid Search + LightGBM. Aunque ambos conjuntos de datos producen resultados similares, el modelo con el conjunto downsampled tiene un mejor balance en términos de recall y F1 Score.
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Evaluación del Modelo

# %% [markdown]
# ### Resumen de resultados

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Para mostrar los resultados de una manera más estructurada y clara, a continuación se muestra una tabla que permitirá comparar fácilmente las métricas de los diferentes modelos, también se muestran visualmente las matrices de confusión de todos los modelos y finalmente una gráfica con todas las curvas ROC de los modelos previamente evaluados.
# </div>

# %%
# Dictionary
resultados = {
    'Modelo': [
        'Regresión Logística', 'K-Nearest Neighbors', 'Random Forest',
        'Grid Search + Random Forest', 'Gradient Boosting Machine',
        'Grid Search + GBM', 'XGBoost',
        'Grid Search + XGBoost', 'LightGBM', 'Grid Search + LightGBM'
    ],
    'AUC-ROC': [
        m1_auc_roc, m2_auc_roc, m3_auc_roc,
        m4_auc_roc, m5_auc_roc, m6_auc_roc,
        m7_auc_roc, m8_auc_roc, m9_auc_roc,
        m10_auc_roc
    ],
    'Accuracy': [
        m1_accuracy, m2_accuracy, m3_accuracy,
        m4_accuracy, m5_accuracy, m6_accuracy,
        m7_accuracy, m8_accuracy, m9_accuracy,
        m10_accuracy
    ],
    'Precisión': [
        m1_precision, m2_precision, m3_precision,
        m4_precision, m5_precision, m6_precision,
        m7_precision, m8_precision, m9_precision,
        m10_precision
    ],
    'Recall': [
        m1_recall, m2_recall, m3_recall,
        m4_recall, m5_recall, m6_recall,
        m7_recall, m8_recall, m9_recall,
        m10_recall
    ],
    'F1 Score': [
        m1_f1, m2_f1, m3_f1,
        m4_f1, m5_f1, m6_f1,
        m7_f1, m8_f1, m9_f1,
        m10_f1
    ],
    'Matriz de Confusión': [
        m1_conf_matrix, m2_conf_matrix, m3_conf_matrix,
        m4_conf_matrix, m5_conf_matrix, m6_conf_matrix,
        m7_conf_matrix, m8_conf_matrix, m9_conf_matrix,
        m10_conf_matrix
    ]
}

# DataFrame
df_resultados = pd.DataFrame(resultados)

# Print
print("\n*****\nResumen de resultados de cada modelo:")
display(df_resultados)
# Out:
# *****
# Resumen de resultados de cada modelo:
#                         Modelo   AUC-ROC  Accuracy  Precisión    Recall  \
# 0          Regresión Logística  0.831666  0.736131   0.901442  0.721848
# 1          K-Nearest Neighbors  0.792257  0.706259   0.906494  0.671800
# 2                Random Forest  0.839343  0.741110   0.913097  0.717998
# 3  Grid Search + Random Forest  0.844507  0.730441   0.918782  0.696824
# 4    Gradient Boosting Machine  0.837294  0.735420   0.910209  0.712223
# 5            Grid Search + GBM  0.840223  0.737553   0.918750  0.707411
# 6                      XGBoost  0.797509  0.709815   0.887117  0.695861
# 7        Grid Search + XGBoost  0.841352  0.729018   0.921795  0.692012
# 8                     LightGBM  0.815981  0.723329   0.904229  0.699711
# 9       Grid Search + LightGBM  0.832004  0.734708   0.910099  0.711261
#
#    F1 Score      Matriz de Confusión
# 0  0.801710  [[285, 82], [289, 750]]
# 1  0.771697  [[295, 72], [341, 698]]
# ...

# %%
# list of Confusion Matrices
matrices = [m1_conf_matrix, m2_conf_matrix, m3_conf_matrix, m4_conf_matrix,
            m5_conf_matrix, m6_conf_matrix, m7_conf_matrix, m8_conf_matrix,
            m9_conf_matrix, m10_conf_matrix]
modelos = ['Regresión Logística', 'KNN Classifier', 'Random Forest',
           'Grid Search + Random Forest', 'GBM', 'Grid Search + GBM',
           'XGBoost', 'Grid Search + XGBoost', 'LightGBM', 'Grid Search + LightGBM']

# Subplots
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))
axes = axes.flatten()

for i, (matrix, model) in enumerate(zip(matrices, modelos)):
    sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues', ax=axes[i])
    axes[i].set_title(f'{model}')
    axes[i].set_xlabel('Predicted')
    axes[i].set_ylabel('True')

# Print
plt.tight_layout()
plt.show()

# %%
# inicialization
falsos_positivos = []
falsos_negativos = []

# Loop
for matriz_confusion in df_resultados['Matriz de Confusión']:
    fp = matriz_confusion[0, 1]
    fn = matriz_confusion[1, 0]
    falsos_positivos.append(fp)
    falsos_negativos.append(fn)

# Bar plot
fig, ax = plt.subplots(figsize=(10, 5))
modelo_labels = df_resultados['Modelo']
x = range(len(modelo_labels))
width = 0.4

# Bars
bar1 = ax.bar(x, falsos_positivos, width, label='Falsos Positivos')
bar2 = ax.bar([i + width for i in x], falsos_negativos,
              width, label='Falsos Negativos')

# Title and labels
ax.set_xlabel('Modelos')
ax.set_ylabel('Cantidad')
ax.set_title('Comparación de Falsos Positivos y Falsos Negativos por Modelo')
ax.set_xticks([i + width / 2 for i in x])
ax.set_xticklabels(modelo_labels, rotation=45, ha='right')
ax.legend()

# Print
plt.tight_layout()
plt.show()

# %%
# List of models
models = [
    ("Modelo 1: Regresión Logística", m1_auc_roc, m1_predictions_proba_valid),
    ("Modelo 2: KNN Clasifier", m2_auc_roc, m2_predictions_proba_valid),
    ("Modelo 3: Random Forest", m3_auc_roc, m3_predictions_proba_valid),
    ("Modelo 4: Grid Search + Random Forest", m4_auc_roc, m4_predictions_proba_valid),
    ("Modelo 5: Gradient Boosting Machine (GBM)", m5_auc_roc, m5_predictions_proba_valid),
    ("Modelo 6: Grid Search + Gradient Boosting Machine (GBM)", m6_auc_roc, m6_predictions_proba_valid),
    ("Modelo 7: XGBoost", m7_auc_roc, m7_predictions_proba_valid),
    ("Modelo 8: Grid Search + XGBoost", m8_auc_roc, m8_predictions_proba_valid),
    ("Modelo 9: LightGBM", m9_auc_roc, m9_predictions_proba_valid),
    ("Modelo 10: Grid Search + LightGBM", m10_auc_roc, m10_predictions_proba_valid),
]

# Plot
plt.figure(figsize=(10, 8))

# ROC Curves
for model_name, auc_roc, predictions_proba in models:
    fpr, tpr, _ = roc_curve(target_valid, predictions_proba)
    plt.plot(fpr, tpr, label='%s (AUC-ROC=%0.4f)' % (model_name, auc_roc))

# Graphs
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curvas ROC Comparativas de los Modelos')
plt.legend(loc='lower right')

# Print
plt.show()

# %% [markdown]
# ### Análisis de resultados

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ <b>AUC-ROC:</b> los modelos Grid Search + Random Forest, Grid Search + Gradient Boosting Machine y Grid Search + Extreme Gradient Boosting (XGBoost) superan el umbral de 0.83 en AUC-ROC; tienen un rendimiento sólido.<br>
# ▶ <b>Accuracy:</b> los modelos Regresión Logística, Random Forest, Gradient Boosting Machine, Grid Search + Extreme Gradient Boosting (XGBoost) y Grid Search + LightGBM obtienen una exactitud superior al 0.73, lo cual representa una alta tasa de clasificación correcta.<br>
# ▶ <b>Precisión y Recall:</b> La mayoría de los modelos tienen una alta precisión en predicciones positivas, algo contrastante con el recall podría mejorar en algunos modelos.<br>
# ▶ <b>F1 Score:</b> Los modelos Regresión Logística y Random Forest tienen los mejores resultados en F1 Score, mostrando un buen equilibrio entre precisión y recall.<br>
# ▶ <b>Matrices de confusión:</b> el Random Forest estándar y Gradient Boosting Machine son los más equilibrados en términos de verdaderos positivos y negativos. Por otro lado se observa que en los modelos hay una tendencia a tener más falsos negativos que falsos positivos, lo que indica una tendencia a subestimar la cancelación de clientes.
# </div>

# %% [markdown]
# ### Selección del modelo con mejor desempeño

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ <b>El Modelo Random Forest es la mejor opción para este proyecto</b>, considerando todas las métricas y la estabilidad en los resultados. Ofrece un alto AUC-ROC, precisión, recall y F1 score, además de presentar una matriz de confusión equilibrada, tender a ser rápido en entrenamiento y un buen rendimiento general en comparación con los otros modelos evaluados.<br>
# ▶ A continuación se muestra el modelo Random Forest con la mejor selección de hiperparámetros resultantes del Grid Search utilizado.
# </div>

# %%
# Model with the Best Hyperparameters
modelf = RandomForestClassifier(
    random_state=12345,
    max_depth=20,
    min_samples_leaf=10,
    n_estimators=50
)

# Downsampling
final_features_downsampled, final_target_downsampled = downsample(
    total_features_train, total_target_train)

# Training
modelf.fit(final_features_downsampled, final_target_downsampled)

# Predictions
mf_predictions_valid = modelf.predict(features_test)
mf_predictions_proba_valid = modelf.predict_proba(features_test)[:, 1]

# %%
# Metrics
mf_auc_roc = roc_auc_score(target_test, mf_predictions_proba_valid)
mf_accuracy = accuracy_score(target_test, mf_predictions_valid)
mf_precision = precision_score(target_test, mf_predictions_valid)
mf_recall = recall_score(target_test, mf_predictions_valid)
mf_f1 = f1_score(target_test, mf_predictions_valid)
mf_conf_matrix = confusion_matrix(target_test, mf_predictions_valid)

# Print
print("\n*****\nModelo final: Random Forest")
print(f"AUC-ROC: {mf_auc_roc:.2f}")
print(f"Accuracy: {mf_accuracy:.2f}")
print(f"Precisión: {mf_precision:.2f}")
print(f"Recall: {mf_recall:.2f}")
print(f"F1 Score: {mf_f1:.2f}")

# Print Confusion Matrix
print("Matriz de Confusión:")
print(mf_conf_matrix)
# Out:
# *****
# Modelo final: Random Forest
# AUC-ROC: 0.86
# Accuracy: 0.76
# Precisión: 0.91
# Recall: 0.74
# F1 Score: 0.81
# Matriz de Confusión:
# [[313  76]
#  [267 751]]

# %%
# Plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=mf_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title(
    "Matriz de Confusión (Modelo final: Random Forest)")
ax1.set_xlabel("Prediction")
ax1.set_ylabel("Actual")
tick_labels = ['False', 'True']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_test, mf_predictions_proba_valid)
ax2.plot(fpr, tpr, label='ROC Curve (AUC-ROC=%0.4f)' % mf_auc_roc)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('Curva ROC (Modelo final: Random Forest)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis del modelo con mejor desempeño

# %% [markdown]
# <div style="color: #196CC4;"> En el conjunto de datos original, existe un desbalance, con más instancias de clientes que no abandonaron (clase negativa) en comparación con aquellos que sí lo hicieron (clase positiva). A continuación, se analizan los resultados para el modelo **Random Forest** y el conjunto de prueba: <br>
# ▶ <b>AUC-ROC:</b> El valor de 0.86 indica que el modelo tiene un buen rendimiento en términos de discriminación entre las clases positivas y negativas. Esto sugiere que el modelo es eficaz para distinguir entre clientes que abandonarán y aquellos que no lo harán.
#
# <br>
# ▶ <b>Accuracy:</b> Con un 76%, el modelo clasifica correctamente una alta proporción de casos, lo cual es positivo. Sin embargo, en problemas de desbalance de clases como este, es crucial también evaluar otras métricas como precisión, recall y F1 Score para obtener una visión completa del rendimiento del modelo.
#
# <br>
# ▶ <b>Precisión:</b> La precisión de 0.91 significa que de todas las predicciones positivas que hizo el modelo, el 91% fueron correctas. Esto indica que cuando el modelo predice que un cliente abandonará, tiene una alta probabilidad de que efectivamente lo haga.
#
# <br>
# ▶ <b>Recall:</b> Con un recall de 0.74, el modelo es efectivo para identificar clientes que tienen una alta probabilidad de abandonar. Sin embargo, un recall de este valor también sugiere que el modelo todavía pierde algunos casos de abandono.
#
# <br>
# ▶ <b>F1 Score:</b> El F1 Score de 0.81, una medida combinada de precisión y recall, muestra un buen equilibrio entre ambas métricas. Esto es particularmente importante en problemas con desbalance de clases, como la predicción de abandono de clientes.
#
# <br>
# ▶ <b>Matriz de confusión:</b>
#
# <ul> <li>Verdaderos positivos = 751: clientes que el modelo predijo correctamente que abandonarían y sí abandonaron.</li> <li>Verdaderos negativos = 313: clientes que el modelo predijo correctamente que no abandonarían y no abandonaron.</li> <li>Falsos positivos = 76: clientes que el modelo predijo incorrectamente que sí abandonarían, pero realmente no abandonaron.</li> <li>Falsos negativos = 267: clientes que el modelo predijo incorrectamente que no abandonarían, pero realmente sí abandonaron.</li> <li>El modelo es efectivo para capturar la mayoría de los casos de clientes que realmente abandonan. Sin embargo, aquellas predicciones falsas pueden llevar a acciones de retención innecesarias o, por el contrario, a la pérdida de oportunidades para retener a clientes que realmente desean abandonar.</li> </ul> <br>
#
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Informe y conclusiones de proyecto

# %% [markdown]
# ### Resumen

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Este proyecto consistió en predecir la cancelación de clientes para Interconnect, utilizando técnicas de aprendizaje automático. Se exploraron cuatro conjuntos de datos principales: contract.csv, personal.csv, internet.csv y phone.csv, los cuales se integraron en un único DataFrame para facilitar el análisis, limpieza y modelado. <br>
# ▶ A través de la aplicación de diversos modelos de clasificación como Regresión Logística, KNN Classifier, Random Forest, XGBoost, y LightGBM (incluyendo una variación con Grid Search para algunos de ellos), se evaluó y seleccionó un modelo final basado en Random Forest por su robustez y desempeño en métricas clave como AUC-ROC, Precisión, Recall y F1 Score.
# </div>

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ El modelo Random Forest ofrece un rendimiento sólido y equilibrado en la predicción de abandono de clientes, destacándose en precisión y en su capacidad para discriminar correctamente entre las clases. A pesar de la existencia de algunos falsos positivos y negativos, la aplicación de este modelo podría contribuir de manera significativa a mejorar las estrategias de retención de clientes.
#
# </div>

# %% [markdown]
# ### Áreas de oportunidad hacia el futuro

# %% [markdown]
# <div style="color: #196CC4;">
# ▶ Los falsos positivos (76) son relativamente bajos en comparación con los verdaderos positivos, lo cual es positivo, pero aún así podrían representar costos adicionales si se toman medidas de retención innecesarias.<br>
# ▶ Los falsos negativos (267) son significativos y representan casos en los que el modelo no identificó correctamente a clientes que sí abandonaron. Este tipo de error es crítico porque representa oportunidades perdidas para intervenir y retener a clientes que sí tienen una alta probabilidad de dejar la empresa.<br>
# ▶ El modelo Random Forest ha demostrado ser eficaz en la tarea de predecir el abandono de clientes, con un F1 robusto y una buena precisión. Sin embargo, el recall podría mejorarse para identificar más casos de clientes que realmente abandonan. <br>
#
# <b>Este modelo puede ser implementado con confianza para apoyar estrategias de retención de clientes. Por otro lado se recomienda monitorear continuamente su desempeño y considerar ajustes adicionales para minimizar tanto los falsos positivos, como los falsos negativos y optimizar el equilibrio entre precisión y recall.</b>
# </div>
